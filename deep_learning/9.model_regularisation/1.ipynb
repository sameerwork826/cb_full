# %%
#Dropout Regularisation randomly dropping out neurons in each set while training

# %%
import pandas as pd
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sonar.all-data")
df.sample(5)
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 23   0.0293  0.0644  0.0390  0.0173  0.0476  0.0816  0.0993  0.0315  0.0736
# 198  0.0116  0.0744  0.0367  0.0225  0.0076  0.0545  0.1110  0.1069  0.1708
# 55   0.0152  0.0102  0.0113  0.0263  0.0097  0.0391  0.0857  0.0915  0.0949
# 75   0.0239  0.0189  0.0466  0.0440  0.0657  0.0742  0.1380  0.1099  0.1384
# 85   0.0188  0.0370  0.0953  0.0824  0.0249  0.0488  0.1424  0.1972  0.1873
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 23   0.0860  ...  0.0035  0.0052  0.0083  0.0078  0.0075  0.0105  0.0160
# 198  0.2271  ...  0.0141  0.0103  0.0100  0.0034  0.0026  0.0037  0.0044
# 55   0.1504  ...  0.0049  0.0041  0.0036  0.0013  0.0046  0.0037  0.0011
# 75   0.1376  ...  0.0091  0.0151  0.0080  0.0018  0.0078  0.0045  0.0026
# 85   0.1806  ...  0.0093  0.0033  0.0113  0.0030  0.0057  0.0090  0.0057
#
#      0.0090  0.0032  R
# 23   0.0095  0.0011  R
# 198  0.0057  0.0035  M
# 55   0.0034  0.0033  R
# 75   0.0036  0.0024  R
# 85   0.0068  0.0024  R
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (207, 61)

# %%
df[60] = df[60].map({'M': 0, 'R': 1})
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nande\.conda\envs\myenv_cb_dl\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\nande\.conda\envs\myenv_cb_dl\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\nande\.conda\envs\myenv_cb_dl\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 60
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[60] = df[60].map({'M': 0, 'R': 1})
#       2 df.head(3)
#
# File c:\Users\nande\.conda\envs\myenv_cb_dl\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\nande\.conda\envs\myenv_cb_dl\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 60
